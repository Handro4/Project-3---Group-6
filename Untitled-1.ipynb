# %%
# Import dependencies
import pandas as pd
import json as js

# %%
# Read in CSV
file = pd.read_csv("../U.S._Chronic_Disease_Indicators__CDI_.csv")
csv = pd.DataFrame(file)
# Out:
# /var/folders/4v/cb_1rxpn3hgb9k0psp8120wm0000gn/T/ipykernel_54721/1953228306.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   file = pd.read_csv("../U.S._Chronic_Disease_Indicators__CDI_.csv")

# %%
#Preview the CSV
csv.head()
# Out:
#    YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 0       2010     2010           OR          Oregon       NVSS
# 1       2019     2019           AZ         Arizona      YRBSS
# 2       2019     2019           OH            Ohio      YRBSS
# 3       2019     2019           US   United States      YRBSS
# 4       2015     2015           VI  Virgin Islands      YRBSS
#
#                     Topic                      Question  Response  \
# 0  Cardiovascular Disease  Mortality from heart failure       NaN
# 1                 Alcohol       Alcohol use among youth       NaN
# 2                 Alcohol       Alcohol use among youth       NaN
# 3                 Alcohol       Alcohol use among youth       NaN
# 4                 Alcohol       Alcohol use among youth       NaN
#
#   DataValueUnit     DataValueType  ... LocationID  TopicID QuestionID  \
# 0           NaN            Number  ...         41      CVD     CVD1_4
# 1             %  Crude Prevalence  ...          4      ALC     ALC1_1
# 2             %  Crude Prevalence  ...         39      ALC     ALC1_1
# 3             %  Crude Prevalence  ...         59      ALC     ALC1_1
# 4             %  Crude Prevalence  ...         78      ALC     ALC1_1
#
#   DataValueTypeID  StratificationCategoryID1  StratificationID1  \
# 0            NMBR                       RACE               AIAN
# 1         CRDPREV                     GENDER               GENF
# 2         CRDPREV                     GENDER               GENM
# 3         CRDPREV                       RACE                ASN
# 4         CRDPREV                     GENDER               GENM
#
#   StratificationCategoryID2 StratificationID2  StratificationCategoryID3  \
# 0                       NaN               NaN                        NaN
# 1                       NaN               NaN                        NaN
# 2                       NaN               NaN                        NaN
# 3                       NaN               NaN                        NaN
# 4                       NaN               NaN                        NaN
#
#    StratificationID3
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 34 columns]

# %%
# Filter down to Topics we want to look at
cdi_csv = csv[(csv["Topic"] == "Asthma") | (csv["Topic"] == "Chronic Obstructive Pulmonary Disease") | (csv["Topic"] == "Cardiovascular Disease")]
cdi_csv
# Out:
#          YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 0             2010     2010           OR       Oregon       NVSS
# 104           2013     2013           IN      Indiana       NVSS
# 107           2016     2016           AR     Arkansas  SEDD; SID
# 108           2017     2017           AZ      Arizona  SEDD; SID
# 109           2016     2016           CA   California  SEDD; SID
# ...            ...      ...          ...          ...        ...
# 1185630       2020     2020           WY      Wyoming      BRFSS
# 1185633       2020     2020           WY      Wyoming      BRFSS
# 1185637       2020     2020           WY      Wyoming      BRFSS
# 1185654       2020     2020           WY      Wyoming      BRFSS
# 1185662       2020     2020           WY      Wyoming      BRFSS
#
#                                          Topic  \
# 0                       Cardiovascular Disease
# 104                     Cardiovascular Disease
# 107                                     Asthma
# 108                                     Asthma
# 109                                     Asthma
# ...                                        ...
# 1185630  Chronic Obstructive Pulmonary Disease
# 1185633                                 Asthma
# 1185637                 Cardiovascular Disease
# 1185654                                 Asthma
# 1185662                 Cardiovascular Disease
#
#                                                   Question  Response  \
# 0                             Mortality from heart failure       NaN
# 104                           Mortality from heart failure       NaN
# 107             Emergency department visit rate for asthma       NaN
# 108             Emergency department visit rate for asthma       NaN
# 109             Emergency department visit rate for asthma       NaN
# ...                                                    ...       ...
# 1185630  Prevalence of chronic obstructive pulmonary di...       NaN
# 1185633  Pneumococcal vaccination among noninstitutiona...       NaN
# 1185637  Influenza vaccination among noninstitutionaliz...       NaN
# 1185654  Influenza vaccination among noninstitutionaliz...       NaN
# 1185662  Pneumococcal vaccination among noninstitutiona...       NaN
#
#              DataValueUnit            DataValueType  ... LocationID  TopicID  \
# 0                      NaN                   Number  ...         41      CVD
# 104      cases per 100,000               Crude Rate  ...         18      CVD
# 107                    NaN                   Number  ...          5      AST
# 108                    NaN                   Number  ...          4      AST
# 109                    NaN                   Number  ...          6      AST
# ...                    ...                      ...  ...        ...      ...
# 1185630                  %         Crude Prevalence  ...         56     COPD
# 1185633                  %         Crude Prevalence  ...         56      AST
# 1185637                  %         Crude Prevalence  ...         56      CVD
# 1185654                  %  Age-adjusted Prevalence  ...         56      AST
# 1185662                  %  Age-adjusted Prevalence  ...         56      CVD
#
#         QuestionID DataValueTypeID  StratificationCategoryID1  \
# 0           CVD1_4            NMBR                       RACE
# 104         CVD1_4         CRDRATE                     GENDER
# 107         AST2_1            NMBR                     GENDER
# 108         AST2_1            NMBR                     GENDER
# 109         AST2_1            NMBR                       RACE
# ...            ...             ...                        ...
# 1185630    COPD2_0         CRDPREV                       RACE
# 1185633     AST6_2         CRDPREV                     GENDER
# 1185637     CVD9_2         CRDPREV                       RACE
# 1185654     AST5_1      AGEADJPREV                     GENDER
# 1185662    CVD10_1      AGEADJPREV                       RACE
#
#          StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0                     AIAN                       NaN               NaN
# 104                   GENM                       NaN               NaN
# 107                   GENM                       NaN               NaN
# 108                   GENM                       NaN               NaN
# 109                    BLK                       NaN               NaN
# ...                    ...                       ...               ...
# 1185630                MRC                       NaN               NaN
# 1185633               GENF                       NaN               NaN
# 1185637                HIS                       NaN               NaN
# 1185654               GENF                       NaN               NaN
# 1185662                HIS                       NaN               NaN
#
#          StratificationCategoryID3  StratificationID3
# 0                              NaN                NaN
# 104                            NaN                NaN
# 107                            NaN                NaN
# 108                            NaN                NaN
# 109                            NaN                NaN
# ...                            ...                ...
# 1185630                        NaN                NaN
# 1185633                        NaN                NaN
# 1185637                        NaN                NaN
# 1185654                        NaN                NaN
# 1185662                        NaN                NaN
#
# [390966 rows x 34 columns]

# %%
# Filter down by year
cdi_csv_year = cdi_csv[(cdi_csv["YearStart"] == 2020)]
cdi_csv_year
# Out:
#          YearStart  YearEnd LocationAbbr LocationDesc DataSource  \
# 173           2020     2020           AL      Alabama       NVSS
# 179           2020     2020           AZ      Arizona       NVSS
# 193           2020     2020           ID        Idaho       NVSS
# 195           2020     2020           IL     Illinois       NVSS
# 228           2020     2020           NY     New York       NVSS
# ...            ...      ...          ...          ...        ...
# 1185630       2020     2020           WY      Wyoming      BRFSS
# 1185633       2020     2020           WY      Wyoming      BRFSS
# 1185637       2020     2020           WY      Wyoming      BRFSS
# 1185654       2020     2020           WY      Wyoming      BRFSS
# 1185662       2020     2020           WY      Wyoming      BRFSS
#
#                                          Topic  \
# 173                                     Asthma
# 179                                     Asthma
# 193                                     Asthma
# 195                                     Asthma
# 228                                     Asthma
# ...                                        ...
# 1185630  Chronic Obstructive Pulmonary Disease
# 1185633                                 Asthma
# 1185637                 Cardiovascular Disease
# 1185654                                 Asthma
# 1185662                 Cardiovascular Disease
#
#                                                   Question  Response  \
# 173                                  Asthma mortality rate       NaN
# 179                                  Asthma mortality rate       NaN
# 193                                  Asthma mortality rate       NaN
# 195                                  Asthma mortality rate       NaN
# 228                                  Asthma mortality rate       NaN
# ...                                                    ...       ...
# 1185630  Prevalence of chronic obstructive pulmonary di...       NaN
# 1185633  Pneumococcal vaccination among noninstitutiona...       NaN
# 1185637  Influenza vaccination among noninstitutionaliz...       NaN
# 1185654  Influenza vaccination among noninstitutionaliz...       NaN
# 1185662  Pneumococcal vaccination among noninstitutiona...       NaN
#
#         DataValueUnit            DataValueType  ... LocationID  TopicID  \
# 173            Number                   Number  ...          1      AST
# 179            Number                   Number  ...          4      AST
# 193            Number                   Number  ...         16      AST
# 195            Number                   Number  ...         17      AST
# 228            Number                   Number  ...         36      AST
# ...               ...                      ...  ...        ...      ...
# 1185630             %         Crude Prevalence  ...         56     COPD
# 1185633             %         Crude Prevalence  ...         56      AST
# 1185637             %         Crude Prevalence  ...         56      CVD
# 1185654             %  Age-adjusted Prevalence  ...         56      AST
# 1185662             %  Age-adjusted Prevalence  ...         56      CVD
#
#         QuestionID DataValueTypeID  StratificationCategoryID1  \
# 173         AST4_1            NMBR                    OVERALL
# 179         AST4_1            NMBR                       RACE
# 193         AST4_1            NMBR                    OVERALL
# 195         AST4_1            NMBR                     GENDER
# 228         AST4_1            NMBR                       RACE
# ...            ...             ...                        ...
# 1185630    COPD2_0         CRDPREV                       RACE
# 1185633     AST6_2         CRDPREV                     GENDER
# 1185637     CVD9_2         CRDPREV                       RACE
# 1185654     AST5_1      AGEADJPREV                     GENDER
# 1185662    CVD10_1      AGEADJPREV                       RACE
#
#          StratificationID1 StratificationCategoryID2 StratificationID2  \
# 173                    OVR                       NaN               NaN
# 179                    WHT                       NaN               NaN
# 193                    OVR                       NaN               NaN
# 195                   GENF                       NaN               NaN
# 228                   AIAN                       NaN               NaN
# ...                    ...                       ...               ...
# 1185630                MRC                       NaN               NaN
# 1185633               GENF                       NaN               NaN
# 1185637                HIS                       NaN               NaN
# 1185654               GENF                       NaN               NaN
# 1185662                HIS                       NaN               NaN
#
#          StratificationCategoryID3  StratificationID3
# 173                            NaN                NaN
# 179                            NaN                NaN
# 193                            NaN                NaN
# 195                            NaN                NaN
# 228                            NaN                NaN
# ...                            ...                ...
# 1185630                        NaN                NaN
# 1185633                        NaN                NaN
# 1185637                        NaN                NaN
# 1185654                        NaN                NaN
# 1185662                        NaN                NaN
#
# [26935 rows x 34 columns]

# %%
# Preview the data to see the data types
cdi_csv_year.dtypes
# Out:
# YearStart                      int64
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# DataSource                    object
# Topic                         object
# Question                      object
# Response                     float64
# DataValueUnit                 object
# DataValueType                 object
# DataValue                     object
# DataValueAlt                 float64
# DataValueFootnoteSymbol       object
# DatavalueFootnote             object
# LowConfidenceLimit           float64
# HighConfidenceLimit          float64
# StratificationCategory1       object
# Stratification1               object
# StratificationCategory2      float64
# Stratification2              float64
# StratificationCategory3      float64
# Stratification3              float64
# GeoLocation                   object
# ResponseID                   float64
# LocationID                     int64
# TopicID                       object
# QuestionID                    object
# DataValueTypeID               object
# StratificationCategoryID1     object
# StratificationID1             object
# StratificationCategoryID2    float64
# StratificationID2            float64
# StratificationCategoryID3    float64
# StratificationID3            float64
# dtype: object

# %%
# Change the dtype of the Value so we can take the mean
cdi_csv_year["DataValue"] = cdi_csv_year["DataValue"].astype(float)
# Out:
# /var/folders/4v/cb_1rxpn3hgb9k0psp8120wm0000gn/T/ipykernel_54721/4147388588.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdi_csv_year["DataValue"] = cdi_csv_year["DataValue"].astype(float)

# %%
# Create new columns to separate lat and long numbers
cdi_csv_year["GeoLocation"] = cdi_csv_year['GeoLocation'].str.replace('POINT ', '').str.replace('(', '').str.replace(')', '')
cdi_csv_year[["Latitude", "Longitude"]] = cdi_csv_year['GeoLocation'].str.split(' ', n=1, expand=True)
cdi_csv_clean = cdi_csv_year.drop(["DataSource", "GeoLocation", "Response", "DataValueUnit", "DataValueFootnoteSymbol", "DatavalueFootnote", "StratificationCategory2",	"Stratification2",	"StratificationCategory3",	"Stratification3", "ResponseID", "TopicID",	"QuestionID",	"DataValueTypeID",	"StratificationCategoryID1",	"StratificationID1",	"StratificationCategoryID2",	"StratificationID2",	"StratificationCategoryID3",	"StratificationID3"], axis=1)
cdi_csv_clean
# Out:
# /var/folders/4v/cb_1rxpn3hgb9k0psp8120wm0000gn/T/ipykernel_54721/1469891845.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdi_csv_year["GeoLocation"] = cdi_csv_year['GeoLocation'].str.replace('POINT ', '').str.replace('(', '').str.replace(')', '')
# /var/folders/4v/cb_1rxpn3hgb9k0psp8120wm0000gn/T/ipykernel_54721/1469891845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdi_csv_year[["Latitude", "Longitude"]] = cdi_csv_year['GeoLocation'].str.split(' ', n=1, expand=True)
# /var/folders/4v/cb_1rxpn3hgb9k0psp8120wm0000gn/T/ipykernel_54721/1469891845.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cdi_csv_year[["Latitude", "Longitude"]] = cdi_csv_year['GeoLocation'].str.split(' ', n=1, expand=True)
#          YearStart  YearEnd LocationAbbr LocationDesc  \
# 173           2020     2020           AL      Alabama
# 179           2020     2020           AZ      Arizona
# 193           2020     2020           ID        Idaho
# 195           2020     2020           IL     Illinois
# 228           2020     2020           NY     New York
# ...            ...      ...          ...          ...
# 1185630       2020     2020           WY      Wyoming
# 1185633       2020     2020           WY      Wyoming
# 1185637       2020     2020           WY      Wyoming
# 1185654       2020     2020           WY      Wyoming
# 1185662       2020     2020           WY      Wyoming
#
#                                          Topic  \
# 173                                     Asthma
# 179                                     Asthma
# 193                                     Asthma
# 195                                     Asthma
# 228                                     Asthma
# ...                                        ...
# 1185630  Chronic Obstructive Pulmonary Disease
# 1185633                                 Asthma
# 1185637                 Cardiovascular Disease
# 1185654                                 Asthma
# 1185662                 Cardiovascular Disease
#
#                                                   Question  \
# 173                                  Asthma mortality rate
# 179                                  Asthma mortality rate
# 193                                  Asthma mortality rate
# 195                                  Asthma mortality rate
# 228                                  Asthma mortality rate
# ...                                                    ...
# 1185630  Prevalence of chronic obstructive pulmonary di...
# 1185633  Pneumococcal vaccination among noninstitutiona...
# 1185637  Influenza vaccination among noninstitutionaliz...
# 1185654  Influenza vaccination among noninstitutionaliz...
# 1185662  Pneumococcal vaccination among noninstitutiona...
#
#                    DataValueType  DataValue  DataValueAlt  LowConfidenceLimit  \
# 173                       Number       63.0          63.0                 NaN
# 179                       Number       74.0          74.0                 NaN
# 193                       Number       23.0          23.0                 NaN
# 195                       Number       88.0          88.0                 NaN
# 228                       Number        NaN           NaN                 NaN
# ...                          ...        ...           ...                 ...
# 1185630         Crude Prevalence        NaN           NaN                 NaN
# 1185633         Crude Prevalence       88.4          88.4                78.1
# 1185637         Crude Prevalence        NaN           NaN                 NaN
# 1185654  Age-adjusted Prevalence       43.1          43.1                32.1
# 1185662  Age-adjusted Prevalence        NaN           NaN                 NaN
#
#          HighConfidenceLimit StratificationCategory1  \
# 173                      NaN                 Overall
# 179                      NaN          Race/Ethnicity
# 193                      NaN                 Overall
# 195                      NaN                  Gender
# 228                      NaN          Race/Ethnicity
# ...                      ...                     ...
# 1185630                  NaN          Race/Ethnicity
# 1185633                 94.2                  Gender
# 1185637                  NaN          Race/Ethnicity
# 1185654                 54.8                  Gender
# 1185662                  NaN          Race/Ethnicity
#
#                           Stratification1  LocationID             Latitude  \
# 173                               Overall           1   -86.63186076199969
# 179                   White, non-Hispanic           4  -111.76381127699972
# 193                               Overall          16   -114.3637300419997
# 195                                Female          17   -88.99771017799969
# 228      American Indian or Alaska Native          36   -75.54397042699964
# ...                                   ...         ...                  ...
# 1185630         Multiracial, non-Hispanic          56  -108.10983035299967
# 1185633                            Female          56  -108.10983035299967
# 1185637                          Hispanic          56  -108.10983035299967
# 1185654                            Female          56  -108.10983035299967
# 1185662                          Hispanic          56  -108.10983035299967
#
#                   Longitude
# 173       32.84057112200048
# 179      34.865970280000454
# 193      43.682630005000476
# 195       40.48501028300046
# 228       42.82700103200045
# ...                     ...
# 1185630   43.23554134300048
# 1185633   43.23554134300048
# 1185637   43.23554134300048
# 1185654   43.23554134300048
# 1185662   43.23554134300048
#
# [26935 rows x 16 columns]

# %%
cdi_csv_year.dtypes
# Out:
# YearStart                      int64
# YearEnd                        int64
# LocationAbbr                  object
# LocationDesc                  object
# DataSource                    object
# Topic                         object
# Question                      object
# Response                     float64
# DataValueUnit                 object
# DataValueType                 object
# DataValue                    float64
# DataValueAlt                 float64
# DataValueFootnoteSymbol       object
# DatavalueFootnote             object
# LowConfidenceLimit           float64
# HighConfidenceLimit          float64
# StratificationCategory1       object
# Stratification1               object
# StratificationCategory2      float64
# Stratification2              float64
# StratificationCategory3      float64
# Stratification3              float64
# GeoLocation                   object
# ResponseID                   float64
# LocationID                     int64
# TopicID                       object
# QuestionID                    object
# DataValueTypeID               object
# StratificationCategoryID1     object
# StratificationID1             object
# StratificationCategoryID2    float64
# StratificationID2            float64
# StratificationCategoryID3    float64
# StratificationID3            float64
# Latitude                      object
# Longitude                     object
# dtype: object

# %%
# Group by Topic and Question and then average
cdi_csv_group = cdi_csv_year.groupby(["Topic", "Question"])["DataValue"].mean().round(2)
cdi_csv_group
# Out:
# Topic                                  Question
# Asthma                                 Asthma mortality rate                                                                                                                     40.62
#                                        Asthma prevalence among women aged 18-44 years                                                                                            13.29
#                                        Current asthma prevalence among adults aged >= 18 years                                                                                   10.39
#                                        Influenza vaccination among noninstitutionalized adults aged 18-64 years with asthma                                                      47.47
#                                        Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma                                                      73.30
#                                        Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with asthma                                                   36.59
#                                        Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with asthma                                                   83.33
# Cardiovascular Disease                 Hospitalization for heart failure among Medicare-eligible persons aged >= 65 years                                                      3734.03
#                                        Influenza vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease or stroke               47.70
#                                        Influenza vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease or stroke               70.95
#                                        Mortality from cerebrovascular disease (stroke)                                                                                          692.19
#                                        Mortality from coronary heart disease                                                                                                   1543.09
#                                        Mortality from diseases of the heart                                                                                                    2675.57
#                                        Mortality from heart failure                                                                                                            1648.59
#                                        Mortality from total cardiovascular diseases                                                                                            3482.11
#                                        Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with a history of coronary heart disease                      41.78
#                                        Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with a history of coronary heart disease                      81.16
# Chronic Obstructive Pulmonary Disease  Hospitalization for chronic obstructive pulmonary disease as any diagnosis among Medicare-eligible persons aged >= 65 years             7242.20
#                                        Hospitalization for chronic obstructive pulmonary disease as first-listed diagnosis among Medicare-eligible persons aged >= 65 years    1117.55
#                                        Influenza vaccination among noninstitutionalized adults aged >= 45 years with chronic obstructive pulmonary disease                       60.00
#                                        Mortality with chronic obstructive pulmonary disease as underlying cause among adults aged >= 45 years                                   731.37
#                                        Mortality with chronic obstructive pulmonary disease as underlying or contributing cause among adults aged >= 45 years                  1526.71
#                                        Pneumococcal vaccination among noninstitutionalized adults aged >= 45 years with chronic obstructive pulmonary disease                    64.24
#                                        Prevalence of chronic obstructive pulmonary disease among adults >= 18                                                                     6.40
#                                        Prevalence of chronic obstructive pulmonary disease among adults >= 45 years                                                              10.05
#                                        Prevalence of current smoking among adults >= 18 with diagnosed chronic obstructive pulmonary disease                                     37.06
#                                        Prevalence of current smoking among adults >= 45 years with diagnosed chronic obstructive pulmonary disease                               35.02
# Name: DataValue, dtype: float64

# %%
# Creating an asthma csv to hold our data
asthma_csv = cdi_csv_year[(cdi_csv_year["Topic"] == "Asthma") & (cdi_csv_year["Question"] == "Current asthma prevalence among adults aged >= 18 years")]
asthma_csv
# Out:
#          YearStart  YearEnd LocationAbbr  LocationDesc DataSource   Topic  \
# 1904          2020     2020           NY      New York      BRFSS  Asthma
# 163643        2020     2020           OH          Ohio      BRFSS  Asthma
# 295798        2020     2020           PA  Pennsylvania      BRFSS  Asthma
# 385812        2020     2020           OR        Oregon      BRFSS  Asthma
# 530929        2020     2020           AR      Arkansas      BRFSS  Asthma
# ...            ...      ...          ...           ...        ...     ...
# 1184716       2020     2020           WY       Wyoming      BRFSS  Asthma
# 1184854       2020     2020           WY       Wyoming      BRFSS  Asthma
# 1184966       2020     2020           WY       Wyoming      BRFSS  Asthma
# 1185204       2020     2020           WY       Wyoming      BRFSS  Asthma
# 1185499       2020     2020           WY       Wyoming      BRFSS  Asthma
#
#                                                   Question  Response  \
# 1904     Current asthma prevalence among adults aged >=...       NaN
# 163643   Current asthma prevalence among adults aged >=...       NaN
# 295798   Current asthma prevalence among adults aged >=...       NaN
# 385812   Current asthma prevalence among adults aged >=...       NaN
# 530929   Current asthma prevalence among adults aged >=...       NaN
# ...                                                    ...       ...
# 1184716  Current asthma prevalence among adults aged >=...       NaN
# 1184854  Current asthma prevalence among adults aged >=...       NaN
# 1184966  Current asthma prevalence among adults aged >=...       NaN
# 1185204  Current asthma prevalence among adults aged >=...       NaN
# 1185499  Current asthma prevalence among adults aged >=...       NaN
#
#         DataValueUnit            DataValueType  ...  QuestionID  \
# 1904                %  Age-adjusted Prevalence  ...      AST1_1
# 163643              %  Age-adjusted Prevalence  ...      AST1_1
# 295798              %         Crude Prevalence  ...      AST1_1
# 385812              %  Age-adjusted Prevalence  ...      AST1_1
# 530929              %         Crude Prevalence  ...      AST1_1
# ...               ...                      ...  ...         ...
# 1184716             %  Age-adjusted Prevalence  ...      AST1_1
# 1184854             %  Age-adjusted Prevalence  ...      AST1_1
# 1184966             %         Crude Prevalence  ...      AST1_1
# 1185204             %  Age-adjusted Prevalence  ...      AST1_1
# 1185499             %         Crude Prevalence  ...      AST1_1
#
#          DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 1904          AGEADJPREV                      RACE               OTH
# 163643        AGEADJPREV                      RACE               MRC
# 295798           CRDPREV                      RACE               HIS
# 385812        AGEADJPREV                      RACE               MRC
# 530929           CRDPREV                      RACE               WHT
# ...                  ...                       ...               ...
# 1184716       AGEADJPREV                      RACE               MRC
# 1184854       AGEADJPREV                      RACE               HIS
# 1184966          CRDPREV                      RACE               WHT
# 1185204       AGEADJPREV                    GENDER              GENM
# 1185499          CRDPREV                      RACE               HIS
#
#          StratificationCategoryID2  StratificationID2  \
# 1904                           NaN                NaN
# 163643                         NaN                NaN
# 295798                         NaN                NaN
# 385812                         NaN                NaN
# 530929                         NaN                NaN
# ...                            ...                ...
# 1184716                        NaN                NaN
# 1184854                        NaN                NaN
# 1184966                        NaN                NaN
# 1185204                        NaN                NaN
# 1185499                        NaN                NaN
#
#         StratificationCategoryID3 StratificationID3             Latitude  \
# 1904                          NaN               NaN   -75.54397042699964
# 163643                        NaN               NaN   -82.40426005599966
# 295798                        NaN               NaN   -77.86070029399963
# 385812                        NaN               NaN  -120.15503132599969
# 530929                        NaN               NaN   -92.27449074299966
# ...                           ...               ...                  ...
# 1184716                       NaN               NaN  -108.10983035299967
# 1184854                       NaN               NaN  -108.10983035299967
# 1184966                       NaN               NaN  -108.10983035299967
# 1185204                       NaN               NaN  -108.10983035299967
# 1185499                       NaN               NaN  -108.10983035299967
#
#                  Longitude
# 1904     42.82700103200045
# 163643   40.06021014100048
# 295798   40.79373015200048
# 385812   44.56744942400047
# 530929   34.74865012400045
# ...                    ...
# 1184716  43.23554134300048
# 1184854  43.23554134300048
# 1184966  43.23554134300048
# 1185204  43.23554134300048
# 1185499  43.23554134300048
#
# [870 rows x 36 columns]

# %%
# Cardiovascular CSV
cardiovascular_csv = cdi_csv_year[(cdi_csv_year["Topic"] == "Cardiovascular Disease") & (cdi_csv_year["Question"] == "Mortality from total cardiovascular diseases")]
cardiovascular_csv
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
# 1935         2020     2020           DC  District of Columbia       NVSS
# 1938         2020     2020           HI                Hawaii       NVSS
# 1955         2020     2020           ME                 Maine       NVSS
# 1958         2020     2020           MT               Montana       NVSS
# 1971         2020     2020           NV                Nevada       NVSS
# ...           ...      ...          ...                   ...        ...
# 333655       2020     2020           RI          Rhode Island       NVSS
# 333672       2020     2020           UT                  Utah       NVSS
# 333683       2020     2020           SC        South Carolina       NVSS
# 333692       2020     2020           MS           Mississippi       NVSS
# 333701       2020     2020           NY              New York       NVSS
#
#                          Topic                                      Question  \
# 1935    Cardiovascular Disease  Mortality from total cardiovascular diseases
# 1938    Cardiovascular Disease  Mortality from total cardiovascular diseases
# 1955    Cardiovascular Disease  Mortality from total cardiovascular diseases
# 1958    Cardiovascular Disease  Mortality from total cardiovascular diseases
# 1971    Cardiovascular Disease  Mortality from total cardiovascular diseases
# ...                        ...                                           ...
# 333655  Cardiovascular Disease  Mortality from total cardiovascular diseases
# 333672  Cardiovascular Disease  Mortality from total cardiovascular diseases
# 333683  Cardiovascular Disease  Mortality from total cardiovascular diseases
# 333692  Cardiovascular Disease  Mortality from total cardiovascular diseases
# 333701  Cardiovascular Disease  Mortality from total cardiovascular diseases
#
#         Response      DataValueUnit DataValueType  ...  QuestionID  \
# 1935         NaN             Number        Number  ...      CVD1_1
# 1938         NaN             Number        Number  ...      CVD1_1
# 1955         NaN             Number        Number  ...      CVD1_1
# 1958         NaN             Number        Number  ...      CVD1_1
# 1971         NaN             Number        Number  ...      CVD1_1
# ...          ...                ...           ...  ...         ...
# 333655       NaN  cases per 100,000    Crude Rate  ...      CVD1_1
# 333672       NaN  cases per 100,000    Crude Rate  ...      CVD1_1
# 333683       NaN  cases per 100,000    Crude Rate  ...      CVD1_1
# 333692       NaN  cases per 100,000    Crude Rate  ...      CVD1_1
# 333701       NaN             Number        Number  ...      CVD1_1
#
#         DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 1935               NMBR                    GENDER              GENF
# 1938               NMBR                      RACE               WHT
# 1955               NMBR                    GENDER              GENM
# 1958               NMBR                      RACE               HIS
# 1971               NMBR                    GENDER              GENM
# ...                 ...                       ...               ...
# 333655          CRDRATE                      RACE               WHT
# 333672          CRDRATE                    GENDER              GENM
# 333683          CRDRATE                      RACE               HIS
# 333692          CRDRATE                      RACE               API
# 333701             NMBR                    GENDER              GENM
#
#         StratificationCategoryID2  StratificationID2  \
# 1935                          NaN                NaN
# 1938                          NaN                NaN
# 1955                          NaN                NaN
# 1958                          NaN                NaN
# 1971                          NaN                NaN
# ...                           ...                ...
# 333655                        NaN                NaN
# 333672                        NaN                NaN
# 333683                        NaN                NaN
# 333692                        NaN                NaN
# 333701                        NaN                NaN
#
#        StratificationCategoryID3 StratificationID3             Latitude  \
# 1935                         NaN               NaN           -77.036871
# 1938                         NaN               NaN  -157.85774940299973
# 1955                         NaN               NaN   -68.98503133599962
# 1958                         NaN               NaN  -109.42442064499971
# 1971                         NaN               NaN  -117.07184056399967
# ...                          ...               ...                  ...
# 333655                       NaN               NaN   -71.52247031399963
# 333672                       NaN               NaN  -111.58713063499971
# 333683                       NaN               NaN   -81.04537120699968
# 333692                       NaN               NaN   -89.53803082499968
# 333701                       NaN               NaN   -75.54397042699964
#
#                  Longitude
# 1935             38.907192
# 1938    21.304850435000446
# 1955    45.254228894000505
# 1958     47.06652897200047
# 1971    39.493240390000494
# ...                    ...
# 333655   41.70828019300046
# 333672  39.360700171000474
# 333683  33.998821303000454
# 333692  32.745510099000455
# 333701   42.82700103200045
#
# [1227 rows x 36 columns]

# %%
# COPD CSV
copd_csv = cdi_csv_year[(cdi_csv_year["Topic"] == "Chronic Obstructive Pulmonary Disease") & (cdi_csv_year["Question"] == "Prevalence of chronic obstructive pulmonary disease among adults >= 18")]
copd_csv
# Out:
#          YearStart  YearEnd LocationAbbr    LocationDesc DataSource  \
# 530930        2020     2020           AR        Arkansas      BRFSS
# 531401        2020     2020           FL         Florida      BRFSS
# 532222        2020     2020           ME           Maine      BRFSS
# 533319        2020     2020           MT         Montana      BRFSS
# 533475        2020     2020           SC  South Carolina      BRFSS
# ...            ...      ...          ...             ...        ...
# 1184705       2020     2020           WY         Wyoming      BRFSS
# 1185096       2020     2020           WY         Wyoming      BRFSS
# 1185242       2020     2020           WY         Wyoming      BRFSS
# 1185422       2020     2020           WY         Wyoming      BRFSS
# 1185630       2020     2020           WY         Wyoming      BRFSS
#
#                                          Topic  \
# 530930   Chronic Obstructive Pulmonary Disease
# 531401   Chronic Obstructive Pulmonary Disease
# 532222   Chronic Obstructive Pulmonary Disease
# 533319   Chronic Obstructive Pulmonary Disease
# 533475   Chronic Obstructive Pulmonary Disease
# ...                                        ...
# 1184705  Chronic Obstructive Pulmonary Disease
# 1185096  Chronic Obstructive Pulmonary Disease
# 1185242  Chronic Obstructive Pulmonary Disease
# 1185422  Chronic Obstructive Pulmonary Disease
# 1185630  Chronic Obstructive Pulmonary Disease
#
#                                                   Question  Response  \
# 530930   Prevalence of chronic obstructive pulmonary di...       NaN
# 531401   Prevalence of chronic obstructive pulmonary di...       NaN
# 532222   Prevalence of chronic obstructive pulmonary di...       NaN
# 533319   Prevalence of chronic obstructive pulmonary di...       NaN
# 533475   Prevalence of chronic obstructive pulmonary di...       NaN
# ...                                                    ...       ...
# 1184705  Prevalence of chronic obstructive pulmonary di...       NaN
# 1185096  Prevalence of chronic obstructive pulmonary di...       NaN
# 1185242  Prevalence of chronic obstructive pulmonary di...       NaN
# 1185422  Prevalence of chronic obstructive pulmonary di...       NaN
# 1185630  Prevalence of chronic obstructive pulmonary di...       NaN
#
#         DataValueUnit            DataValueType  ...  QuestionID  \
# 530930              %         Crude Prevalence  ...     COPD2_0
# 531401              %         Crude Prevalence  ...     COPD2_0
# 532222              %  Age-adjusted Prevalence  ...     COPD2_0
# 533319              %         Crude Prevalence  ...     COPD2_0
# 533475              %         Crude Prevalence  ...     COPD2_0
# ...               ...                      ...  ...         ...
# 1184705             %  Age-adjusted Prevalence  ...     COPD2_0
# 1185096             %         Crude Prevalence  ...     COPD2_0
# 1185242             %         Crude Prevalence  ...     COPD2_0
# 1185422             %         Crude Prevalence  ...     COPD2_0
# 1185630             %         Crude Prevalence  ...     COPD2_0
#
#          DataValueTypeID StratificationCategoryID1 StratificationID1  \
# 530930           CRDPREV                    GENDER              GENM
# 531401           CRDPREV                      RACE               OTH
# 532222        AGEADJPREV                    GENDER              GENF
# 533319           CRDPREV                      RACE               OTH
# 533475           CRDPREV                    GENDER              GENF
# ...                  ...                       ...               ...
# 1184705       AGEADJPREV                      RACE               MRC
# 1185096          CRDPREV                      RACE               HIS
# 1185242          CRDPREV                    GENDER              GENM
# 1185422          CRDPREV                      RACE               WHT
# 1185630          CRDPREV                      RACE               MRC
#
#          StratificationCategoryID2  StratificationID2  \
# 530930                         NaN                NaN
# 531401                         NaN                NaN
# 532222                         NaN                NaN
# 533319                         NaN                NaN
# 533475                         NaN                NaN
# ...                            ...                ...
# 1184705                        NaN                NaN
# 1185096                        NaN                NaN
# 1185242                        NaN                NaN
# 1185422                        NaN                NaN
# 1185630                        NaN                NaN
#
#         StratificationCategoryID3 StratificationID3             Latitude  \
# 530930                        NaN               NaN   -92.27449074299966
# 531401                        NaN               NaN   -81.92896053899966
# 532222                        NaN               NaN   -68.98503133599962
# 533319                        NaN               NaN  -109.42442064499971
# 533475                        NaN               NaN   -81.04537120699968
# ...                           ...               ...                  ...
# 1184705                       NaN               NaN  -108.10983035299967
# 1185096                       NaN               NaN  -108.10983035299967
# 1185242                       NaN               NaN  -108.10983035299967
# 1185422                       NaN               NaN  -108.10983035299967
# 1185630                       NaN               NaN  -108.10983035299967
#
#                   Longitude
# 530930    34.74865012400045
# 531401   28.932040377000476
# 532222   45.254228894000505
# 533319    47.06652897200047
# 533475   33.998821303000454
# ...                     ...
# 1184705   43.23554134300048
# 1185096   43.23554134300048
# 1185242   43.23554134300048
# 1185422   43.23554134300048
# 1185630   43.23554134300048
#
# [870 rows x 36 columns]
